# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
saudi_cases = pd.read_csv('saudi-arabia-coronavirus-disease-covid-19-situation.csv' , sep=';')

# %%
saudi_cases
# Out:
#        Daily / Cumulative Indicator        Date Event             City  \
# 0              Cumulative     Cases  2021-01-18   NaN       ʻUrayʻIrah
# 1              Cumulative     Cases  2021-01-21   NaN       ʻUrayʻIrah
# 2              Cumulative     Cases  2021-01-23   NaN       ʻUrayʻIrah
# 3              Cumulative     Cases  2021-01-24   NaN       ʻUrayʻIrah
# 4              Cumulative     Cases  2021-01-25   NaN       ʻUrayʻIrah
# ...                   ...       ...         ...   ...              ...
# 363693         Cumulative    Active  2021-01-14   NaN   Al QuwayʻIyyah
# 363694         Cumulative    Active  2021-01-15   NaN  Al Muzahimiyyah
# 363695         Cumulative    Active  2021-01-15   NaN      Rijal Al Ma
# 363696         Cumulative    Active  2021-01-10   NaN            Sajir
# 363697         Cumulative    Active  2021-01-11   NaN            Sajir
#
#                 Region  Cases (person)
# 0       Eastern Region             164
# ...

# %%
saudi_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363698 entries, 0 to 363697
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Daily / Cumulative  363698 non-null  object
#  1   Indicator           363698 non-null  object
#  2   Date                363698 non-null  object
#  3   Event               1900 non-null    object
#  4   City                363698 non-null  object
#  5   Region              363698 non-null  object
#  6   Cases (person)      363698 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 19.4+ MB

# %%
saudi_cases['country'] = 'Saudi Arabia'

# %%
saudi_cases['Daily / Cumulative'].value_counts()
# Out:
# Cumulative    283297
# Daily          80401
# Name: Daily / Cumulative, dtype: int64

# %%
saudi_cases['Indicator'].value_counts()
# Out:
# Cases          124217
# Recoveries     119639
# Active          80344
# Mortalities     38067
# Tested            994
# Critical          437
# Name: Indicator, dtype: int64

# %%
saudi_cases[saudi_cases['Indicator'] == 'Tested']
# Out:
#        Daily / Cumulative Indicator        Date  \
# 64853               Daily    Tested  2020-03-07
# 64854               Daily    Tested  2020-03-16
# 64855               Daily    Tested  2020-03-22
# 64856               Daily    Tested  2020-04-03
# 64857               Daily    Tested  2020-04-04
# ...                   ...       ...         ...
# 346426         Cumulative    Tested  2021-06-27
# 346427         Cumulative    Tested  2021-06-28
# 346428         Cumulative    Tested  2021-06-29
# 346429         Cumulative    Tested  2021-07-02
# 346430         Cumulative    Tested  2021-07-05
#
#                                       Event   City Region  Cases (person)  \
# 64853                                   NaN  Total  Total            1982
# 64854              Gov / private suspension  Total  Total            3555
# 64855                                   NaN  Total  Total            6033
# 64856                                   NaN  Total  Total            8012
# ...

# %%
saudi_cases[saudi_cases['Indicator'] == 'Critical'].sort_values(by='Date')
# Out:
#        Daily / Cumulative Indicator        Date Event   City Region  \
# 216543         Cumulative  Critical  2020-05-02   NaN  Total  Total
# 216544         Cumulative  Critical  2020-05-03   NaN  Total  Total
# 346173         Cumulative  Critical  2020-05-04   NaN  Total  Total
# 346174         Cumulative  Critical  2020-05-05   NaN  Total  Total
# 229921         Cumulative  Critical  2020-05-06   NaN  Total  Total
# ...                   ...       ...         ...   ...    ...    ...
# 230004         Cumulative  Critical  2021-07-08   NaN  Total  Total
# 230005         Cumulative  Critical  2021-07-09   NaN  Total  Total
# 104691         Cumulative  Critical  2021-07-10   NaN  Total  Total
# 230006         Cumulative  Critical  2021-07-11   NaN  Total  Total
# 230007         Cumulative  Critical  2021-07-12   NaN  Total  Total
#
#         Cases (person)       country
# 216543             257  Saudi Arabia
# 216544             287  Saudi Arabia
# ...

# %%
saudi_cases[saudi_cases['Indicator'] == 'Recoveries'].sort_values(by='Date')
# Out:
#        Daily / Cumulative   Indicator        Date Event                  City  \
# 120550              Daily  Recoveries  2020-03-12   NaN              Al Qatif
# 182750         Cumulative  Recoveries  2020-03-12   NaN                 Total
# 242529         Cumulative  Recoveries  2020-03-12   NaN              Al Qatif
# 334433              Daily  Recoveries  2020-03-12   NaN                 Total
# 49787          Cumulative  Recoveries  2020-03-13   NaN                 Total
# ...                   ...         ...         ...   ...                   ...
# 49770          Cumulative  Recoveries  2021-07-12   NaN         Al Hinakiyyah
# 182720         Cumulative  Recoveries  2021-07-12   NaN  Makkah Al Mukarramah
# 49772          Cumulative  Recoveries  2021-07-12   NaN      Mihd  Adh Dhahab
# 49764          Cumulative  Recoveries  2021-07-12   NaN            Al Mikhwah
# 334430              Daily  Recoveries  2021-07-12   NaN                Laylá
#
# ...

# %%
saudi_cases[saudi_cases['Indicator'] == 'Mortalities'].sort_values(by='Date')
# Out:
#        Daily / Cumulative    Indicator        Date Event  \
# 49886               Daily  Mortalities  2020-03-24   NaN
# 288174         Cumulative  Mortalities  2020-03-24   NaN
# 183823         Cumulative  Mortalities  2020-03-24   NaN
# 50687               Daily  Mortalities  2020-03-24   NaN
# 299282              Daily  Mortalities  2020-03-25   NaN
# ...                   ...          ...         ...   ...
# 52637          Cumulative  Mortalities  2021-07-12   NaN
# 52638          Cumulative  Mortalities  2021-07-12   NaN
# 52639          Cumulative  Mortalities  2021-07-12   NaN
# 187967         Cumulative  Mortalities  2021-07-12   NaN
# 105198         Cumulative  Mortalities  2021-07-12   NaN
#
#                             City                    Region  Cases (person)  \
# 49886   Al Madinah Al Munawwarah  Al Madinah Al Munawwarah               1
# 288174                     Total                     Total               1
# ...

# %%
saudi_cases[saudi_cases['Indicator'] == 'Critical'].sort_values(by='Date')
# Out:
#        Daily / Cumulative Indicator        Date Event   City Region  \
# 216543         Cumulative  Critical  2020-05-02   NaN  Total  Total
# 216544         Cumulative  Critical  2020-05-03   NaN  Total  Total
# 346173         Cumulative  Critical  2020-05-04   NaN  Total  Total
# 346174         Cumulative  Critical  2020-05-05   NaN  Total  Total
# 229921         Cumulative  Critical  2020-05-06   NaN  Total  Total
# ...                   ...       ...         ...   ...    ...    ...
# 230004         Cumulative  Critical  2021-07-08   NaN  Total  Total
# 230005         Cumulative  Critical  2021-07-09   NaN  Total  Total
# 104691         Cumulative  Critical  2021-07-10   NaN  Total  Total
# 230006         Cumulative  Critical  2021-07-11   NaN  Total  Total
# 230007         Cumulative  Critical  2021-07-12   NaN  Total  Total
#
#         Cases (person)       country
# 216543             257  Saudi Arabia
# 216544             287  Saudi Arabia
# ...

# %%
saudi_cases['Region'].value_counts()
# Out:
# Ar Riyad                    60317
# Eastern Region              51525
# Makkah Al Mukarramah        46445
# Aseer                       43917
# Jazan                       32741
# Al Qaseem                   26572
# Al Madinah Al Munawwarah    18469
# Al Bahah                    15439
# Hail                        14463
# Tabuk                       14273
# Al Jawf                     12345
# Najran                      11851
# Northern Borders            10498
# Total                        4843
# Name: Region, dtype: int64

# %% [markdown]
# - date is not datetime type
# - data set should be sorted by date
# - total shloud be dorpped
# - some regions has wrong name
# - Cases (person) need to be rename
# - country name coulmn need to added
# - Indicator ( Cases , Mortalities , Tested only needed and Critical)
# - population coulmn need to be added from outsourse to be compared
# - Daily / Cumulative cloum should be seprated in to cloumns

# %% [markdown]
# new data structure:
# - Date
# - country
# - region
# - new tested
# - total tested
# - new cases
# - total cases
# - new Recoveries
# - total Recoveries
# - new death
# - total death

# %%
#### date is not datetime type
saudi_cases['Date'] = saudi_cases['Date'].astype('datetime64[ns]')

# %%
saudi_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363698 entries, 0 to 363697
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Daily / Cumulative  363698 non-null  object
#  1   Indicator           363698 non-null  object
#  2   Date                363698 non-null  datetime64[ns]
#  3   Event               1900 non-null    object
#  4   City                363698 non-null  object
#  5   Region              363698 non-null  object
#  6   Cases (person)      363698 non-null  int64
#  7   country             363698 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 22.2+ MB

# %% [markdown]
# #####  data set should be sorted by date

# %%
saudi_cases = saudi_cases.sort_values(by='Date')
saudi_cases.head()
# Out:
#        Daily / Cumulative Indicator       Date                   Event  \
# 216438         Cumulative    Active 2020-03-02  First case of COVID-19
# 160572              Daily     Cases 2020-03-02  First case of COVID-19
# 346347         Cumulative    Tested 2020-03-02  First case of COVID-19
# 30508          Cumulative     Cases 2020-03-02  First case of COVID-19
# 82250          Cumulative     Cases 2020-03-02  First case of COVID-19
#
#             City          Region  Cases (person)       country
# 216438     Total           Total               1  Saudi Arabia
# 160572  Al Qatif  Eastern Region               1  Saudi Arabia
# 346347     Total           Total             160  Saudi Arabia
# 30508      Total           Total               1  Saudi Arabia
# 82250   Al Qatif  Eastern Region               1  Saudi Arabia

# %%
saudi_cases = saudi_cases[saudi_cases['Region'] != 'Total']
saudi_cases = saudi_cases[saudi_cases['City'] != 'Total']
saudi_cases.head()
# Out:
#        Daily / Cumulative Indicator       Date                   Event  \
# 160572              Daily     Cases 2020-03-02  First case of COVID-19
# 82250          Cumulative     Cases 2020-03-02  First case of COVID-19
# 307203         Cumulative    Active 2020-03-02  First case of COVID-19
# 158292         Cumulative     Cases 2020-03-03        Umrah suspension
# 52755          Cumulative    Active 2020-03-03        Umrah suspension
#
#             City          Region  Cases (person)       country
# 160572  Al Qatif  Eastern Region               1  Saudi Arabia
# 82250   Al Qatif  Eastern Region               1  Saudi Arabia
# 307203  Al Qatif  Eastern Region               1  Saudi Arabia
# 158292  Al Qatif  Eastern Region               1  Saudi Arabia
# 52755   Al Qatif  Eastern Region               1  Saudi Arabia

# %%
#### some regions has wrong name 

saudi_cases.Region.value_counts()
# Out:
# Ar Riyad                    60317
# Eastern Region              51525
# Makkah Al Mukarramah        46445
# Aseer                       43917
# Jazan                       32741
# Al Qaseem                   26572
# Al Madinah Al Munawwarah    18469
# Al Bahah                    15439
# Hail                        14463
# Tabuk                       14273
# Al Jawf                     12345
# Najran                      11851
# Northern Borders            10498
# Name: Region, dtype: int64

# %%
date = saudi_cases['Date'].unique()

# %%
saudi_cases[(saudi_cases['Daily / Cumulative'] == 'Daily')&(saudi_cases['Indicator'] == 'Cases')].sort_values(by='Date')
# Out:
#        Daily / Cumulative Indicator       Date                   Event  \
# 160572              Daily     Cases 2020-03-02  First case of COVID-19
# 76475               Daily     Cases 2020-03-04        Umrah suspension
# 160573              Daily     Cases 2020-03-05                     NaN
# 22546               Daily     Cases 2020-03-07                     NaN
# 160574              Daily     Cases 2020-03-08                     NaN
# ...                   ...       ...        ...                     ...
# 158207              Daily     Cases 2021-07-12                     NaN
# 158208              Daily     Cases 2021-07-12                     NaN
# 158209              Daily     Cases 2021-07-12                     NaN
# 158201              Daily     Cases 2021-07-12                     NaN
# 321558              Daily     Cases 2021-07-12                     NaN
#
#                     City                Region  Cases (person)       country
# ...

# %%
Daily = saudi_cases[(saudi_cases['Daily / Cumulative'] == 'Daily')]
Daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78452 entries, 160572 to 242418
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Daily / Cumulative  78452 non-null  object
#  1   Indicator           78452 non-null  object
#  2   Date                78452 non-null  datetime64[ns]
#  3   Event               440 non-null    object
#  4   City                78452 non-null  object
#  5   Region              78452 non-null  object
#  6   Cases (person)      78452 non-null  int64
#  7   country             78452 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 5.4+ MB

# %%
regions = list(Daily['Region'].unique())
date = list(Daily['Date'].unique())
len(date) , len(regions)
# Out:
# (496, 13)

# %%
new_cases = []
new_death = []
new_recoveries =[]
date_new = []
regions_new = []
for i in date:
    for j in regions:
        new_cases.append(Daily[Daily['Region'] == '{}'.format(j)][Daily['Date'] == '{}'.format(i)]\
                         [Daily['Indicator'] == 'Cases']['Cases (person)'].sum())
        new_death.append(Daily[Daily['Region'] == '{}'.format(j)][Daily['Date'] == '{}'.format(i)]\
                         [Daily['Indicator'] == 'Mortalities']['Cases (person)'].sum())
        new_recoveries.append(Daily[Daily['Region'] == '{}'.format(j)][Daily['Date'] == '{}'.format(i)]\
                         [Daily['Indicator'] == 'Recoveries']['Cases (person)'].sum())
        date_new.append(i)
        regions_new.append(j)
# Out:
# <ipython-input-23-30d1226ce9f6>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_cases.append(Daily[Daily['Region'] == '{}'.format(j)][Daily['Date'] == '{}'.format(i)]\
# <ipython-input-23-30d1226ce9f6>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_death.append(Daily[Daily['Region'] == '{}'.format(j)][Daily['Date'] == '{}'.format(i)]\
# <ipython-input-23-30d1226ce9f6>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_recoveries.append(Daily[Daily['Region'] == '{}'.format(j)][Daily['Date'] == '{}'.format(i)]\

# %%
new_df = pd.DataFrame()
new_df['date'] = date_new
new_df['country'] = 'Saudi Arabia'
new_df['Region'] = regions_new
new_df['New_Cases'] = new_cases
new_df['New_Death'] =new_death
new_df['New_Recoveries']=new_recoveries
new_df
# Out:
#            date       country                Region  New_Cases  New_Death  \
# 0    2020-03-02  Saudi Arabia        Eastern Region          1          0
# 1    2020-03-02  Saudi Arabia              Ar Riyad          0          0
# 2    2020-03-02  Saudi Arabia  Makkah Al Mukarramah          0          0
# 3    2020-03-02  Saudi Arabia                 Jazan          0          0
# 4    2020-03-02  Saudi Arabia                 Aseer          0          0
# ...         ...           ...                   ...        ...        ...
# 6443 2021-07-12  Saudi Arabia             Al Qaseem         55          0
# 6444 2021-07-12  Saudi Arabia                Najran         39          0
# 6445 2021-07-12  Saudi Arabia      Northern Borders         23          0
# 6446 2021-07-12  Saudi Arabia                  Hail         49          1
# 6447 2021-07-12  Saudi Arabia               Al Jawf          8          0
#
#       New_Recoveries
# 0                  0
# 1                  0
# ...

# %%
new_df['Region'].value_counts()
# Out:
# Northern Borders            496
# Eastern Region              496
# Al Bahah                    496
# Aseer                       496
# Najran                      496
# Ar Riyad                    496
# Tabuk                       496
# Al Madinah Al Munawwarah    496
# Makkah Al Mukarramah        496
# Al Qaseem                   496
# Jazan                       496
# Al Jawf                     496
# Hail                        496
# Name: Region, dtype: int64

# %%
new_df.describe()
# Out:
#          New_Cases    New_Death  New_Recoveries
# count  6448.000000  6448.000000     6448.000000
# mean     78.122519     1.241625       75.198821
# std     172.431478     2.831703      183.880908
# min       0.000000     0.000000        0.000000
# 25%       5.000000     0.000000        3.000000
# 50%      19.000000     0.000000       15.000000
# 75%      69.000000     1.000000       61.000000
# max    2609.000000    36.000000     3701.000000

# %%
cleand_df = new_df.copy()

# %%
cleand_df['Total_Cases'] = 0
cleand_df['Total_Deaths'] = 0
cleand_df['Total_Recoveries'] = 0

# %%
regions = list(cleand_df['Region'].unique())

# %%
total_Cases = []
total_deaths = []
total_recoveries=[]

for i in regions:
    cases_total = 0
    deaths_total = 0
    recoveries_total =0
    for j in cleand_df.index:
        if(cleand_df['Region'][j] == i):
            cases_total += cleand_df['New_Cases'][j]
            deaths_total += cleand_df['New_Death'][j]
            recoveries_total += cleand_df['New_Recoveries'][j]
            cleand_df['Total_Cases'][j] = cases_total
            cleand_df['Total_Deaths'][j] = deaths_total
            cleand_df['Total_Recoveries'][j] = recoveries_total
# Out:
# <ipython-input-30-b8107707f17f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleand_df['Total_Cases'][j] = cases_total
# <ipython-input-30-b8107707f17f>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleand_df['Total_Deaths'][j] = deaths_total
# <ipython-input-30-b8107707f17f>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleand_df['Total_Recoveries'][j] = recoveries_total

# %%
cleand_df[cleand_df['date'] == '2021-07-12']
# Out:
#            date       country                    Region  New_Cases  New_Death  \
# 6435 2021-07-12  Saudi Arabia            Eastern Region        189          4
# 6436 2021-07-12  Saudi Arabia                  Ar Riyad        327          2
# 6437 2021-07-12  Saudi Arabia      Makkah Al Mukarramah        283          5
# 6438 2021-07-12  Saudi Arabia                     Jazan         92          1
# 6439 2021-07-12  Saudi Arabia                     Aseer        135          1
# 6440 2021-07-12  Saudi Arabia  Al Madinah Al Munawwarah         45          0
# 6441 2021-07-12  Saudi Arabia                  Al Bahah         26          0
# 6442 2021-07-12  Saudi Arabia                     Tabuk         24          0
# 6443 2021-07-12  Saudi Arabia                 Al Qaseem         55          0
# 6444 2021-07-12  Saudi Arabia                    Najran         39          0
# 6445 2021-07-12  Saudi Arabia          Northern Borders         23          0
# ...

# %%
cleand_df['New_Cases'].sum()
# Out:
# 503734

# %%
cleand_df[cleand_df['date'] == '2021-07-12']['Total_Cases'].sum()
# Out:
# 503734

# %%
plt.figure(figsize=(8, 4), dpi=100)
plt.plot(cleand_df[cleand_df['Region'] == 'Ar Riyad']['date'],cleand_df[cleand_df['Region'] == 'Ar Riyad']['Total_Cases'] ,  label ='Riyad');
plt.plot(cleand_df[cleand_df['Region'] == 'Eastern Region']['date'],cleand_df[cleand_df['Region'] == 'Eastern Region']['Total_Cases'],label ='Eastern Region');
plt.plot(cleand_df[cleand_df['Region'] == 'Makkah Al Mukarramah']['date'],cleand_df[cleand_df['Region'] == 'Makkah Al Mukarramah']['Total_Cases'],label ='Makkah');
plt.legend();

# %%
plt.figure(figsize=(8, 4), dpi=100)
plt.plot(cleand_df[cleand_df['Region'] == 'Ar Riyad']['date'],cleand_df[cleand_df['Region'] == 'Ar Riyad']['Total_Deaths'],label ='Riyad');
plt.plot(cleand_df[cleand_df['Region'] == 'Eastern Region']['date'],cleand_df[cleand_df['Region'] == 'Eastern Region']['Total_Deaths'],label ='Eastern Region');
plt.plot(cleand_df[cleand_df['Region'] == 'Makkah Al Mukarramah']['date'],cleand_df[cleand_df['Region'] == 'Makkah Al Mukarramah']['Total_Deaths'],label ='Makkah');
plt.legend();

# %%
plt.figure(figsize=(8, 4), dpi=100)
plt.plot(cleand_df[cleand_df['Region'] == 'Ar Riyad']['date'],cleand_df[cleand_df['Region'] == 'Ar Riyad']['Total_Recoveries'],label ='Riyad');
plt.plot(cleand_df[cleand_df['Region'] == 'Eastern Region']['date'],cleand_df[cleand_df['Region'] == 'Eastern Region']['Total_Recoveries'],label ='Eastern Region');
plt.plot(cleand_df[cleand_df['Region'] == 'Makkah Al Mukarramah']['date'],cleand_df[cleand_df['Region'] == 'Makkah Al Mukarramah']['Total_Recoveries'],label ='Makkah');
plt.legend();

# %%
plt.bar(cleand_df[cleand_df['Region'] == 'Ar Riyad']['date'],cleand_df[cleand_df['Region'] == 'Ar Riyad']['New_Death'])
# Out:
# <BarContainer object of 496 artists>

# %%
cleand_df.to_csv('cleaned-dataset.csv',index=False)
